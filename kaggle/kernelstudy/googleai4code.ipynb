# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os  
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/kaggle"

# %%
cd /content/drive/MyDrive/kaggle
# Out:
# /content/drive/MyDrive/kaggle

# %%
# !chmod 600 kaggle.json

# %%
# !kaggle competitions list
# Out:
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes         52           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes         98           False
# store-sales-time-series-forecasting            2030-06-30 23:59:00  Getting Started  Knowledge        626           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        123           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       1246            True
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      15112           False
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       3995           False
# connectx                                       2030-01-01 00:00:00  Getting Started  Knowledge        197           False
# nlp-getting-started                            2030-01-01 00:00:00  Getting Started  Knowledge        805           False
# spaceship-titanic                              2030-01-01 00:00:00  Getting Started  Knowledge       2299           False
# competitive-data-science-predict-future-sales  2022-12-31 23:59:00  Playground           Kudos      15124           False
# google-universal-image-embedding               2022-10-10 23:59:00  Research           $50,000        188           False
# jpx-tokyo-stock-exchange-prediction            2022-10-07 23:59:00  Featured           $63,000       2085            True
# mayo-clinic-strip-ai                           2022-10-05 23:59:00  Research           $10,000        141            True
# hubmap-organ-segmentation                      2022-09-22 23:59:00  Research           $60,000        409           False
# amex-default-prediction                        2022-08-24 23:59:00  Featured          $100,000       3014            True
# feedback-prize-effectiveness                   2022-08-23 23:59:00  Featured           $55,000        993            True
# AI4Code                                        2022-08-11 23:59:00  Featured          $150,000        912            True
# tabular-playground-series-jul-2022             2022-07-31 23:59:00  Playground            Swag        900           False
# smartphone-decimeter-2022                      2022-07-29 23:59:00  Research           $10,000        524            True

# %%
# !kaggle competitions download -c AI4Code

# %%
# !unzip AI4Code.zip

# %%
import json
from pathlib import Path

import numpy as np
import pandas as pd
from scipy import sparse
from tqdm import tqdm
import glob

pd.options.display.width = 180
pd.options.display.max_colwidth = 120

data_dir = Path('/content/drive/MyDrive/kaggle')

# %%
NUM_TRAIN = 10000

def read_notebook(path):
    return (
        pd.read_json(
            path,
            dtype={'cell_type': 'category', 'source': 'str'})
        .assign(id=path.stem)
        .rename_axis('cell_id')
    )


paths_train = list((data_dir/'train').glob('*.json'))[:NUM_TRAIN]
notebooks_train = [
    read_notebook(path) for path in tqdm(paths_train, desc='Train NBs')
]
df = (
    pd.concat(notebooks_train)
    .set_index('id', append=True)
    .swaplevel()
    .sort_index(level='id', sort_remaining=False)
)

df
# Out:
# Train NBs:   0%|          | 0/10000 [04:22<?, ?it/s]
# Train NBs: 100%|██████████| 10000/10000 [1:13:05<00:00,  2.28it/s]
#                         cell_type                                                                                                                   source
# id             cell_id
# d1446e16134090 2ac26f41      code  # This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/pyt...
#                f41ac7a7      code                     #load the csv file and make the data frame\nstartup_df = pd.read_csv('../input/startup_funding.csv')
#                d7401a80      code                                                                                      #display the data frame\nstartup_df
#                4cc9e3d4      code  #display the how many rows and columns\nprint("The dataframe has {} rows and {} columns".format(startup_df.shape[0],...
#                ebff3d0a      code                                                                    #display the data types of columns\nstartup_df.dtypes
# ...                           ...                                                                                                                      ...
# e6e3cd8c11cc85 8ba83088  markdown                                                                                                  Checking dataframe head
#                fce3c8c4  markdown                                                         A bar plot can be used to show population level in each district
#                aed3f808  markdown                                                                            Lets check all keys available in geojson file
#                cb833fe4  markdown                                                                   Now, dataframe has new column named "Population scale"
#                ca16dea3  markdown                                                                                     Merge both dataframe according to id
#
# [454736 rows x 2 columns]

# %%
nb_id = df.index.unique('id')[6]
print('Notebook:', nb_id)

print('The diisordered notebook:')
nb = df.loc[nb_id, :]
display(nb)
print()
# Out:
# Notebook: d150b8fd780dce
# The diisordered notebook:
#          cell_type                                                                                                                   source
# cell_id
# b41404df      code  import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n%matplotlib inline\...
# ea827f4c      code                                                               df = pd.read_csv('../input/ecommerce/Ecommerce Customers')
# 29b6024e      code                                                                                                                df.head()
# c3d47f09      code                                                                                                            df.describe()
# 494c8ad8      code                                                                                                                df.info()
# da8667b1      code                                                                       sns.heatmap(df.corr(), annot=True, cmap='viridis')
# 1ba2c8f4      code  df.columns\nnum = ['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership', 'Yearly Amount Sp...
# 9c04e11b      code                                 for i in num:\n    print(df[i].mean())\n    sns.displot(df[i], kde=True)\n    plt.show()
# 9c96b5aa      code                          sns.set_style('whitegrid')\nsns.jointplot(x='Time on Website',y='Yearly Amount Spent', data=df)
# 2e5d7748      code                                                          sns.jointplot(x='Time on App',y='Yearly Amount Spent', data=df)
# 05e89645      code                                                 sns.jointplot(x='Length of Membership',y='Yearly Amount Spent', data=df)
# 9ffa9696      code                                              sns.jointplot(x='Time on App',y='Length of Membership', data=df,kind='hex')
# bc51f59d      code                                                                                                         sns.pairplot(df)
# 8225cbfa      code                               sns.lmplot(x='Length of Membership',y='Yearly Amount Spent', data=df,scatter_kws={'s':20})
# b320f186      code                                                                                                               df.columns
# 078021e8      code  x = df[['Avg. Session Length', 'Time on App',\n       'Time on Website', 'Length of Membership']]\ny = df['Yearly Am...
# 3fe3c6e8      code                                    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=101)
# fa629343      code                                                                                                  lm = LinearRegression()
# 568c173b      code                                                                                                 lm.fit(x_train, y_train)
# da45e992      code                                                                                                                 lm.coef_
# 86e41ec5      code                                                                                                            lm.intercept_
# 1f0ff6f6      code                                                                                                pred = lm.predict(x_test)
# 856ebf17      code                                               plt.scatter(y_test, pred)\nplt.xlabel('Y Test')\nplt.ylabel('Predicted Y')
# e1aa2452      code                                                                                              from sklearn import metrics
# cc90ef8d      code  MAE = metrics.mean_absolute_error(y_test,pred)\nMSE = metrics.mean_squared_error(y_test,pred)\nRMSE= np.sqrt(MSE)\np...
# d5f2d698      code                                                                            sns.displot((y_test-pred), bins=50, kde=True)
# 4d90620f      code                                                              cdf = pd.DataFrame(lm.coef_,x.columns,['Coefficient'])\ncdf
# 5f4c382e  markdown                                                           **Create an instance of a LinearRegression() model named lm.**
# 4e49d713  markdown  ___\n**Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the co...
# 3d840f22  markdown                                        **Check the head of customers, and check out its info() and describe() methods.**
# cfdbeef7  markdown  ## Exploratory Data Analysis\n\n**Let's explore the data!**\n\nFor the rest of the exercise we'll only be using the ...
# 508fa6c5  markdown                          ## Great Job!\n\nCongrats on your contract work! The company loved the insights! Let's move on.
# decd5437  markdown                                  **Do you think the company should focus more on their mobile app or on their website?**
# a3cc3912  markdown                           ** Use jointplot to create a 2D hex bin plot comparing Time on App and Length of Membership.**
# 769a3da3  markdown  ## Predicting Test Data\nNow that we have fit our model, let's evaluate its performance by predicting off the test v...
# f5b3a70f  markdown                                                                              **Print out the coefficients of the model**
# d072cc33  markdown  ## Imports\n** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline \n(You'll import sklearn as...
# 44e55312  markdown  ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size...
# 852a0643  markdown  ## Conclusion\nWe still want to figure out the answer to the original question, do we focus our efforst on mobile ap...
# c7ff90ef  markdown                                                                                  ** Train/fit lm on the training data.**
# b1477535  markdown                                                                                                 *Answer here* mobile app
# b0c719fe  markdown                           **Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**
# a5e4e59e  markdown                                                                                               ans = Length of membership
# 363c1b4d  markdown                                           ## Training the Model\n\nNow its time to train our model on our training data!
# b23ab009  markdown               **Create a linear model plot (using seaborn's lmplot) of  Yearly Amount Spent vs. Length of Membership. **
# d38a626a  markdown                                                               ** Do the same but with the Time on App column instead. **
# 49ee70a4  markdown                                          ** Create a scatterplot of the real test values versus the predicted values. **
# 2015e5b3  markdown  ## Residuals\n\nYou should have gotten a very good model with a good fit. Let's quickly explore the residuals to mak...
# 3039877a  markdown  ## Evaluating the Model\n\nLet's evaluate our model performance by calculating the residual sum of squares and the e...
# 09495be2  markdown  **Let's explore these types of relationships across the entire data set. Use [pairplot](https://stanford.edu/~mwasko...
# 79acfdc8  markdown                                                                                       *Answer here* Length of mem is imp
# 2ce84014  markdown  # Linear Regression Project\n\nCongratulations! You just got some contract work with an Ecommerce company based in N...
# f0f3f36e  markdown  ## Get the Data\n\nWe'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas E...
# ff06ada3  markdown                                                                          ** How can you interpret these coefficients? **
# 790c320b  markdown  ## Training and Testing Data\n\nNow that we've explored the data a bit, let's go ahead and split the data into train...

# %%
df_orders = pd.read_csv('/content/drive/MyDrive/kaggle/train_orders.csv',
                        index_col='id',
                        squeeze=True,).str.split()
df_orders
# Out:
# id
# 00001756c60be8    [1862f0a6, 448eb224, 2a9e43d6, 7e2f170a, 038b763d, 77e56113, 2eefe0ef, 1ae087ab, 0beab1cd, 8ffe0b25, 9a78ab76, 0d136...
# 00015c83e2717b    [2e94bd7a, 3e99dee9, b5e286ea, da4f7550, c417225b, 51e3cd89, 2600b4eb, 75b65993, cf195f8b, 25699d02, 72b3201a, f2c75...
# 0001bdd4021779    [3fdc37be, 073782ca, 8ea7263c, 80543cd8, 38310c80, 073e27e5, 015d52a4, ad7679ef, 7fde4f04, 07c52510, 0a1a7a39, 0bcd3...
# 0001daf4c2c76d    [97266564, a898e555, 86605076, 76cc2642, ef279279, df6c939f, 2476da96, 00f87d0a, ae93e8e6, 58aadb1d, d20b0094, 986fd...
# 0002115f48f982                                 [9ec225f0, 18281c6c, e3b6b115, 4a044c54, 365fe576, a3188e54, b3f6e12d, ee7655ca, 84125b7a]
#                                                                            ...
# fffc30d5a0bc46    [09727c0c, ff1ea6a0, ddfef603, a01ce9b3, 3ba953ee, bf92a015, f4a0492a, 095812e6, 53125cfe, aa32a700, 63340e73, 06d8c...
# fffc3b44869198    [978a5137, faa48f03, 28dfb12a, eea2e812, 64fef97c, 4e0d1510, 58e68f2c, 8784e700, 4bd5a4cf, dc14bfec, 2aff7603, 8047d...
# fffc63ff750064    [5015c300, 411b85d9, 8238198c, f4781d1d, b5532930, e1f223e5, e7e67119, 4aaf741d, 7229cce6, a7fa3628, e4c2fa86, 1f8f9...
# fffcd063cda949    [7e6266ad, d8281fc5, d4ffcaef, 3e0e4a47, 21387fc8, cc229f9a, baed9c8b, d1bb21aa, 82979992, 65f95dad, eba4fa9e, c97e2...
# fffe1d764579d5    [1a63248d, 9c3b96a5, 1398a873, 4e2d4c2d, f71c538e, 8b44a5e8, 385dff7a, b8254ef8, 4d0e433e, debc496c, e15ae953, e4d79...
# Name: cell_order, Length: 139256, dtype: object

# %%
cell_order = df_orders.loc[nb_id]

print('The ordered notebook:')
nb.loc[cell_order, :]
# Out:
# The ordered notebook:
#          cell_type                                                                                                                   source
# cell_id
# 2ce84014  markdown  # Linear Regression Project\n\nCongratulations! You just got some contract work with an Ecommerce company based in N...
# d072cc33  markdown  ## Imports\n** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline \n(You'll import sklearn as...
# b41404df      code  import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n%matplotlib inline\...
# f0f3f36e  markdown  ## Get the Data\n\nWe'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas E...
# ea827f4c      code                                                               df = pd.read_csv('../input/ecommerce/Ecommerce Customers')
# 3d840f22  markdown                                        **Check the head of customers, and check out its info() and describe() methods.**
# 29b6024e      code                                                                                                                df.head()
# c3d47f09      code                                                                                                            df.describe()
# 494c8ad8      code                                                                                                                df.info()
# cfdbeef7  markdown  ## Exploratory Data Analysis\n\n**Let's explore the data!**\n\nFor the rest of the exercise we'll only be using the ...
# da8667b1      code                                                                       sns.heatmap(df.corr(), annot=True, cmap='viridis')
# 1ba2c8f4      code  df.columns\nnum = ['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership', 'Yearly Amount Sp...
# 9c04e11b      code                                 for i in num:\n    print(df[i].mean())\n    sns.displot(df[i], kde=True)\n    plt.show()
# 4e49d713  markdown  ___\n**Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the co...
# 9c96b5aa      code                          sns.set_style('whitegrid')\nsns.jointplot(x='Time on Website',y='Yearly Amount Spent', data=df)
# d38a626a  markdown                                                               ** Do the same but with the Time on App column instead. **
# 2e5d7748      code                                                          sns.jointplot(x='Time on App',y='Yearly Amount Spent', data=df)
# 05e89645      code                                                 sns.jointplot(x='Length of Membership',y='Yearly Amount Spent', data=df)
# a3cc3912  markdown                           ** Use jointplot to create a 2D hex bin plot comparing Time on App and Length of Membership.**
# 9ffa9696      code                                              sns.jointplot(x='Time on App',y='Length of Membership', data=df,kind='hex')
# 09495be2  markdown  **Let's explore these types of relationships across the entire data set. Use [pairplot](https://stanford.edu/~mwasko...
# bc51f59d      code                                                                                                         sns.pairplot(df)
# b0c719fe  markdown                           **Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**
# a5e4e59e  markdown                                                                                               ans = Length of membership
# b23ab009  markdown               **Create a linear model plot (using seaborn's lmplot) of  Yearly Amount Spent vs. Length of Membership. **
# 8225cbfa      code                               sns.lmplot(x='Length of Membership',y='Yearly Amount Spent', data=df,scatter_kws={'s':20})
# 790c320b  markdown  ## Training and Testing Data\n\nNow that we've explored the data a bit, let's go ahead and split the data into train...
# b320f186      code                                                                                                               df.columns
# 078021e8      code  x = df[['Avg. Session Length', 'Time on App',\n       'Time on Website', 'Length of Membership']]\ny = df['Yearly Am...
# 44e55312  markdown  ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size...
# 3fe3c6e8      code                                    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=101)
# 363c1b4d  markdown                                           ## Training the Model\n\nNow its time to train our model on our training data!
# 5f4c382e  markdown                                                           **Create an instance of a LinearRegression() model named lm.**
# fa629343      code                                                                                                  lm = LinearRegression()
# c7ff90ef  markdown                                                                                  ** Train/fit lm on the training data.**
# 568c173b      code                                                                                                 lm.fit(x_train, y_train)
# f5b3a70f  markdown                                                                              **Print out the coefficients of the model**
# da45e992      code                                                                                                                 lm.coef_
# 86e41ec5      code                                                                                                            lm.intercept_
# 769a3da3  markdown  ## Predicting Test Data\nNow that we have fit our model, let's evaluate its performance by predicting off the test v...
# 1f0ff6f6      code                                                                                                pred = lm.predict(x_test)
# 49ee70a4  markdown                                          ** Create a scatterplot of the real test values versus the predicted values. **
# 856ebf17      code                                               plt.scatter(y_test, pred)\nplt.xlabel('Y Test')\nplt.ylabel('Predicted Y')
# 3039877a  markdown  ## Evaluating the Model\n\nLet's evaluate our model performance by calculating the residual sum of squares and the e...
# e1aa2452      code                                                                                              from sklearn import metrics
# cc90ef8d      code  MAE = metrics.mean_absolute_error(y_test,pred)\nMSE = metrics.mean_squared_error(y_test,pred)\nRMSE= np.sqrt(MSE)\np...
# 2015e5b3  markdown  ## Residuals\n\nYou should have gotten a very good model with a good fit. Let's quickly explore the residuals to mak...
# d5f2d698      code                                                                            sns.displot((y_test-pred), bins=50, kde=True)
# 852a0643  markdown  ## Conclusion\nWe still want to figure out the answer to the original question, do we focus our efforst on mobile ap...
# 4d90620f      code                                                              cdf = pd.DataFrame(lm.coef_,x.columns,['Coefficient'])\ncdf
# ff06ada3  markdown                                                                          ** How can you interpret these coefficients? **
# 79acfdc8  markdown                                                                                       *Answer here* Length of mem is imp
# decd5437  markdown                                  **Do you think the company should focus more on their mobile app or on their website?**
# b1477535  markdown                                                                                                 *Answer here* mobile app
# 508fa6c5  markdown                          ## Great Job!\n\nCongrats on your contract work! The company loved the insights! Let's move on.

# %%
def get_ranks(base, derived):
  return [base.index(d) for d in derived]

cell_ranks = get_ranks(cell_order, list(nb.index))
nb.insert(0, 'rank', cell_ranks)

nb
# Out:
#           rank cell_type                                                                                                                   source
# cell_id
# b41404df     2      code  import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\nimport seaborn as sns\n%matplotlib inline\...
# ea827f4c     4      code                                                               df = pd.read_csv('../input/ecommerce/Ecommerce Customers')
# 29b6024e     6      code                                                                                                                df.head()
# c3d47f09     7      code                                                                                                            df.describe()
# 494c8ad8     8      code                                                                                                                df.info()
# da8667b1    10      code                                                                       sns.heatmap(df.corr(), annot=True, cmap='viridis')
# 1ba2c8f4    11      code  df.columns\nnum = ['Avg. Session Length', 'Time on App','Time on Website', 'Length of Membership', 'Yearly Amount Sp...
# 9c04e11b    12      code                                 for i in num:\n    print(df[i].mean())\n    sns.displot(df[i], kde=True)\n    plt.show()
# 9c96b5aa    14      code                          sns.set_style('whitegrid')\nsns.jointplot(x='Time on Website',y='Yearly Amount Spent', data=df)
# 2e5d7748    16      code                                                          sns.jointplot(x='Time on App',y='Yearly Amount Spent', data=df)
# 05e89645    17      code                                                 sns.jointplot(x='Length of Membership',y='Yearly Amount Spent', data=df)
# 9ffa9696    19      code                                              sns.jointplot(x='Time on App',y='Length of Membership', data=df,kind='hex')
# bc51f59d    21      code                                                                                                         sns.pairplot(df)
# 8225cbfa    25      code                               sns.lmplot(x='Length of Membership',y='Yearly Amount Spent', data=df,scatter_kws={'s':20})
# b320f186    27      code                                                                                                               df.columns
# 078021e8    28      code  x = df[['Avg. Session Length', 'Time on App',\n       'Time on Website', 'Length of Membership']]\ny = df['Yearly Am...
# 3fe3c6e8    30      code                                    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3, random_state=101)
# fa629343    33      code                                                                                                  lm = LinearRegression()
# 568c173b    35      code                                                                                                 lm.fit(x_train, y_train)
# da45e992    37      code                                                                                                                 lm.coef_
# 86e41ec5    38      code                                                                                                            lm.intercept_
# 1f0ff6f6    40      code                                                                                                pred = lm.predict(x_test)
# 856ebf17    42      code                                               plt.scatter(y_test, pred)\nplt.xlabel('Y Test')\nplt.ylabel('Predicted Y')
# e1aa2452    44      code                                                                                              from sklearn import metrics
# cc90ef8d    45      code  MAE = metrics.mean_absolute_error(y_test,pred)\nMSE = metrics.mean_squared_error(y_test,pred)\nRMSE= np.sqrt(MSE)\np...
# d5f2d698    47      code                                                                            sns.displot((y_test-pred), bins=50, kde=True)
# 4d90620f    49      code                                                              cdf = pd.DataFrame(lm.coef_,x.columns,['Coefficient'])\ncdf
# 5f4c382e    32  markdown                                                           **Create an instance of a LinearRegression() model named lm.**
# 4e49d713    13  markdown  ___\n**Use seaborn to create a jointplot to compare the Time on Website and Yearly Amount Spent columns. Does the co...
# 3d840f22     5  markdown                                        **Check the head of customers, and check out its info() and describe() methods.**
# cfdbeef7     9  markdown  ## Exploratory Data Analysis\n\n**Let's explore the data!**\n\nFor the rest of the exercise we'll only be using the ...
# 508fa6c5    54  markdown                          ## Great Job!\n\nCongrats on your contract work! The company loved the insights! Let's move on.
# decd5437    52  markdown                                  **Do you think the company should focus more on their mobile app or on their website?**
# a3cc3912    18  markdown                           ** Use jointplot to create a 2D hex bin plot comparing Time on App and Length of Membership.**
# 769a3da3    39  markdown  ## Predicting Test Data\nNow that we have fit our model, let's evaluate its performance by predicting off the test v...
# f5b3a70f    36  markdown                                                                              **Print out the coefficients of the model**
# d072cc33     1  markdown  ## Imports\n** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline \n(You'll import sklearn as...
# 44e55312    29  markdown  ** Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set test_size...
# 852a0643    48  markdown  ## Conclusion\nWe still want to figure out the answer to the original question, do we focus our efforst on mobile ap...
# c7ff90ef    34  markdown                                                                                  ** Train/fit lm on the training data.**
# b1477535    53  markdown                                                                                                 *Answer here* mobile app
# b0c719fe    22  markdown                           **Based off this plot what looks to be the most correlated feature with Yearly Amount Spent?**
# a5e4e59e    23  markdown                                                                                               ans = Length of membership
# 363c1b4d    31  markdown                                           ## Training the Model\n\nNow its time to train our model on our training data!
# b23ab009    24  markdown               **Create a linear model plot (using seaborn's lmplot) of  Yearly Amount Spent vs. Length of Membership. **
# d38a626a    15  markdown                                                               ** Do the same but with the Time on App column instead. **
# 49ee70a4    41  markdown                                          ** Create a scatterplot of the real test values versus the predicted values. **
# 2015e5b3    46  markdown  ## Residuals\n\nYou should have gotten a very good model with a good fit. Let's quickly explore the residuals to mak...
# 3039877a    43  markdown  ## Evaluating the Model\n\nLet's evaluate our model performance by calculating the residual sum of squares and the e...
# 09495be2    20  markdown  **Let's explore these types of relationships across the entire data set. Use [pairplot](https://stanford.edu/~mwasko...
# 79acfdc8    51  markdown                                                                                       *Answer here* Length of mem is imp
# 2ce84014     0  markdown  # Linear Regression Project\n\nCongratulations! You just got some contract work with an Ecommerce company based in N...
# f0f3f36e     3  markdown  ## Get the Data\n\nWe'll work with the Ecommerce Customers csv file from the company. It has Customer info, suchas E...
# ff06ada3    50  markdown                                                                          ** How can you interpret these coefficients? **
# 790c320b    26  markdown  ## Training and Testing Data\n\nNow that we've explored the data a bit, let's go ahead and split the data into train...

# %%
from pandas.testing import assert_frame_equal

assert_frame_equal(nb.loc[cell_order, :], nb.sort_values('rank'))

# %%
df_orders_ = df_orders.to_frame().join(
    df.reset_index('cell_id').groupby('id')['cell_id'].apply(list),
    how='right',
)

ranks = {}
for id_, cell_order, cell_id in df_orders_.itertuples():
    ranks[id_] = {'cell_id': cell_id, 'rank': get_ranks(cell_order, cell_id)}

df_ranks = (
    pd.DataFrame
    .from_dict(ranks, orient='index')
    .rename_axis('id')
    .apply(pd.Series.explode)
    .set_index('cell_id', append=True)
)

df_ranks
# Out:
#                         rank
# id             cell_id
# d1446e16134090 2ac26f41    0
#                f41ac7a7    1
#                d7401a80    2
#                4cc9e3d4    3
#                ebff3d0a    4
# ...                      ...
# e6e3cd8c11cc85 8ba83088   14
#                fce3c8c4   29
#                aed3f808    3
#                cb833fe4   37
#                ca16dea3   23
#
# [454736 rows x 1 columns]

# %%
df_ancestors = pd.read_csv('/content/drive/MyDrive/kaggle/train_ancestors.csv', index_col='id')
df_ancestors
# Out:
#                ancestor_id       parent_id
# id
# 00001756c60be8    945aea18             NaN
# 00015c83e2717b    aa2da37e  317b65d12af9df
# 0001bdd4021779    a7711fde             NaN
# 0001daf4c2c76d    090152ca             NaN
# 0002115f48f982    272b483a             NaN
# ...                    ...             ...
# fffc30d5a0bc46    6aed207b             NaN
# fffc3b44869198    a6aaa8d7             NaN
# fffc63ff750064    0a1b5b65             NaN
# fffcd063cda949    d971e960             NaN
# fffe1d764579d5    3c40bfa6             NaN
#
# [139256 rows x 2 columns]

# %%
from sklearn.model_selection import GroupShuffleSplit

NVALID = 0.1

splitter = GroupShuffleSplit(n_splits=1, test_size=NVALID, random_state=0)

ids = df.index.unique('id')
ancestors = df_ancestors.loc[ids, 'ancestor_id']
ids_train, ids_valid = next(splitter.split(ids, groups=ancestors))
ids_train, ids_valid = ids[ids_train], ids[ids_valid]

df_train = df.loc[ids_train, :]
df_valid = df.loc[ids_valid, :]

# %%
df.to_csv('df.csv')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(min_df=0.01)
X_train = tfidf.fit_transform(df_train['source'].astype(str))
y_train = df_ranks.loc[ids_train].to_numpy()
groups = df_ranks.loc[ids_train].groupby('id').size().to_numpy()

# %%
X_train = sparse.hstack((
    X_train,
    np.where(
        df_train['cell_type'] == 'code',
        df_train.groupby(['id', 'cell_type']).cumcount().to_numpy() + 1,
        0,
    ).reshape(-1, 1)
))
print(X_train.shape)
# Out:
# (409389, 285)

# %%
from xgboost import XGBRanker

model = XGBRanker(
    min_child_weight=10,
    subsample=0.5,
    tree_method='hist',
)
model.fit(X_train, y_train, group=groups)
# Out:
# XGBRanker(min_child_weight=10, subsample=0.5, tree_method='hist')

# %%
X_valid = tfidf.transform(df_valid['source'].astype(str))
y_valid = df_orders.loc[ids_valid]

X_valid = sparse.hstack((
    X_valid,
    np.where(
        df_valid['cell_type'] == 'code',
        df_valid.groupby(['id', 'cell_type']).cumcount().to_numpy() + 1,
        0,
    ).reshape(-1, 1)
))

# %%
y_pred = pd.DataFrame({'rank': model.predict(X_valid)}, index=df_valid.index)
y_pred = (
    y_pred
    .sort_values(['id', 'rank']) 
    .reset_index('cell_id')
    .groupby('id')['cell_id'].apply(list)
)
y_pred.head(10)
# Out:
# id
# d1446e16134090    [2ac26f41, f41ac7a7, d7401a80, 4cc9e3d4, ebff3d0a, 14316a63, 91f13b4c, 09d1e305, 195fab20, bee96839, 1cd54b30, 3d896...
# d14e9de0f70a5d    [d7dd5767, f4a9ecb1, bc5eeab0, 265ea94d, a43b68ff, 0bd1ed10, ee7323b9, f792dffe, 68322dbf, ce57181e, b2e1f177, b06a4...
# d14fbd648b370b    [e849af9f, 9007ccd9, c937419b, 6e3ec9dc, b482bb62, 426d1cf8, 407fc47e, 8e5c3e66, ffae14fc, 6004d82e, 0f4619a6, 6599b...
# d15a2c75e2d3e8    [505aff8a, f68a7fc8, fd62ff2f, b9e4f44a, d64b3081, 2e6e8007, 3a7d7c81, f69dae28, f6bf142e, b086b16a, 244b83ae, 36bdf...
# d16ab3106de5bc             [62063b17, 768074f8, 26e01546, da9a2f17, 073c5609, 67fdbd6d, 9d074f3d, c9513124, 6b30eb11, f937490f, 8de3e130]
# d1b602f41b8712    [58ebdd2e, 95c8dbae, ac18d49d, a638b4e8, cfe651ea, 75dbc896, d41ca2bf, a657ba0a, 5ecfc391, 8a514cd9, d42450dc, d979a...
# d1b67261d15dc0    [883020dd, 674d1014, 4bc8c507, e6da1799, daf67104, 9daa578d, d2720308, 5cbd1c10, 60f50f5b, 00938280, c9a61a0f, c11e1...
# d211bdefdf6016    [62fc4211, d2a649f7, 26c1bd00, efc234c5, aa65c188, e0e8480c, 4c41387c, 10be0b1f, 79463d13, 6040bf16, e6470cd2, 7958e...
# d2569e87a3d9a7    [14344cda, e2fe0af5, e68821b8, 9601e556, 3a91c45c, 17ca78df, 67fdd3e7, fe1176b5, 5f262b98, e6f2734a, 783b67ba, 335b3...
# d25a8ab6118dae    [53728ebf, e4d39959, 2419c9d4, 3385d5a4, 20269561, d2c17dcc, b5f1dd59, 0aed0e27, 3cb16f89, fd037ad4, 8710b5ce, b18cf...
# Name: cell_id, dtype: object

# %%
nb_id = df_valid.index.get_level_values('id').unique()[8]

display(df.loc[nb_id])
display(df.loc[nb_id].loc[y_pred.loc[nb_id]])
# Out:
#          cell_type                                                                                                                   source
# cell_id
# 14344cda      code  # This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/pyt...
# e2fe0af5      code                             import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\n%matplotlib inline
# e68821b8      code                              df = pd.read_csv("/kaggle/input/brasilian-houses-to-rent/houses_to_rent_v2.csv")\ndf.info()
# 9601e556      code                                                                                                               df.head(3)
# 3a91c45c      code  df['floor'] = pd.to_numeric(df['floor'], errors='coerce')\ndf['floor'] = df['floor'].fillna(df['floor'].median()).as...
# 17ca78df      code                       import seaborn\nplt.figure(figsize=(5, 3))\nplt.tight_layout()\nseaborn.distplot(df['total (R$)'])
# 67fdd3e7      code                                                         plt.figure(figsize=(5, 3))\ndf['total (R$)'].plot.box(grid=True)
# fe1176b5      code                                                     rows = df[df['total (R$)']>50000].index\ndf.drop(rows, inplace=True)
# 5f262b98      code                                       plt.figure(figsize=(5, 3))\nplt.tight_layout()\nseaborn.distplot(df['total (R$)'])
# 783b67ba      code                                                         plt.figure(figsize=(5, 3))\ndf['total (R$)'].plot.box(grid=True)
# db827ba0      code                                                                                                               df.head(3)
# 8b3b1795      code                                                                    X = df.iloc[:, :-1].values\ny = df.iloc[:, -1].values
# 4abeeca5      code  from sklearn.preprocessing import LabelEncoder, OneHotEncoder\nfrom sklearn.compose import ColumnTransformer\nle = L...
# f6093094      code  from sklearn.model_selection import train_test_split\nX_train, X_test, y_train, y_test = train_test_split(X, y, test...
# 6f0c19dc      code       from sklearn.linear_model import LinearRegression\nregressor = LinearRegression()\nregressor.fit(X_train, y_train)
# f60a85e1      code                                                                                       y_pred = regressor.predict(X_test)
# abd5bff4      code                                  act_vs_pred = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
# b35522d1      code                                                                 df1 = act_vs_pred[:20]\ndf1.plot(kind='bar')\nplt.show()
# 0b1b3a52      code  from sklearn.metrics import r2_score, mean_squared_error\nprint('Mean Squared Error:', mean_squared_error(y_test, y_...
# d4d0fb3f      code                                                                                              residuals = y_test - y_pred
# 76a2c6ab      code                                                                                              seaborn.distplot(residuals)
# 5043bf67      code             import scipy as sp\nfig, ax = plt.subplots()\n_, (_, _, r) = sp.stats.probplot(residuals, plot=ax, fit=True)
# f5839ba0      code                                                                  np.mean(residuals) # mean of the residuals is near to 0
# 74a49038      code  import statsmodels.api as sm\nacf = sm.graphics.tsa.plot_acf(residuals)\nacf.show()\n# No auto correlation of residuals
# e6f2734a  markdown                                                                                                            **Read data**
# c1be68e1  markdown                                                                                                         **Linear model**
# a3f3a6c1  markdown                                                                                                       **Pre processing**
# 3c3a346d  markdown                                                                                                        Importing library
# 066600b7  markdown                                                                                                  **Removal of outliers**
# 335b3071  markdown                                                                                                **Train test data split**
#          cell_type                                                                                                                   source
# cell_id
# 14344cda      code  # This Python 3 environment comes with many helpful analytics libraries installed\n# It is defined by the kaggle/pyt...
# e2fe0af5      code                             import numpy as np\nimport pandas as pd\nimport matplotlib.pyplot as plt\n%matplotlib inline
# e68821b8      code                              df = pd.read_csv("/kaggle/input/brasilian-houses-to-rent/houses_to_rent_v2.csv")\ndf.info()
# 9601e556      code                                                                                                               df.head(3)
# 3a91c45c      code  df['floor'] = pd.to_numeric(df['floor'], errors='coerce')\ndf['floor'] = df['floor'].fillna(df['floor'].median()).as...
# 17ca78df      code                       import seaborn\nplt.figure(figsize=(5, 3))\nplt.tight_layout()\nseaborn.distplot(df['total (R$)'])
# 67fdd3e7      code                                                         plt.figure(figsize=(5, 3))\ndf['total (R$)'].plot.box(grid=True)
# fe1176b5      code                                                     rows = df[df['total (R$)']>50000].index\ndf.drop(rows, inplace=True)
# 5f262b98      code                                       plt.figure(figsize=(5, 3))\nplt.tight_layout()\nseaborn.distplot(df['total (R$)'])
# e6f2734a  markdown                                                                                                            **Read data**
# 783b67ba      code                                                         plt.figure(figsize=(5, 3))\ndf['total (R$)'].plot.box(grid=True)
# 335b3071  markdown                                                                                                **Train test data split**
# db827ba0      code                                                                                                               df.head(3)
# 8b3b1795      code                                                                    X = df.iloc[:, :-1].values\ny = df.iloc[:, -1].values
# 4abeeca5      code  from sklearn.preprocessing import LabelEncoder, OneHotEncoder\nfrom sklearn.compose import ColumnTransformer\nle = L...
# a3f3a6c1  markdown                                                                                                       **Pre processing**
# 3c3a346d  markdown                                                                                                        Importing library
# 066600b7  markdown                                                                                                  **Removal of outliers**
# f6093094      code  from sklearn.model_selection import train_test_split\nX_train, X_test, y_train, y_test = train_test_split(X, y, test...
# 6f0c19dc      code       from sklearn.linear_model import LinearRegression\nregressor = LinearRegression()\nregressor.fit(X_train, y_train)
# f60a85e1      code                                                                                       y_pred = regressor.predict(X_test)
# abd5bff4      code                                  act_vs_pred = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
# b35522d1      code                                                                 df1 = act_vs_pred[:20]\ndf1.plot(kind='bar')\nplt.show()
# 0b1b3a52      code  from sklearn.metrics import r2_score, mean_squared_error\nprint('Mean Squared Error:', mean_squared_error(y_test, y_...
# c1be68e1  markdown                                                                                                         **Linear model**
# d4d0fb3f      code                                                                                              residuals = y_test - y_pred
# 76a2c6ab      code                                                                                              seaborn.distplot(residuals)
# 5043bf67      code             import scipy as sp\nfig, ax = plt.subplots()\n_, (_, _, r) = sp.stats.probplot(residuals, plot=ax, fit=True)
# f5839ba0      code                                                                  np.mean(residuals) # mean of the residuals is near to 0
# 74a49038      code  import statsmodels.api as sm\nacf = sm.graphics.tsa.plot_acf(residuals)\nacf.show()\n# No auto correlation of residuals

# %%
from bisect import bisect

def count_inversions(a):
  inversions = 0
  sorted_so_far = []
  for i, u in enumerate(a):
    j = bisect(sorted_so_far, u)
    inversions += i - j
    sorted_so_far.insert(j, u)
  return inversions

def kendall_tau(ground_truth, predictions):
  total_inversions = 0
  total_2max = 0
  for gt, pred in zip(ground_truth, predictions):
    ranks = [gt.index(x) for x in pred]
    total_inversions += count_inversions(ranks)
    n = len(gt)
    total_2max += n * (n - 1)
  return 1 - 4 * total_inversions / total_2max

# %%
y_dummy = df_valid.reset_index('cell_id').groupby('id')['cell_id'].apply(list)
kendall_tau(y_valid, y_dummy)

# %%
kendall_tau(y_valid, y_pred)
# Out:
# 0.5879245257689806

# %%
paths_test = list((data_dir/'test').glob('*.json'))
notebooks_test = [
    read_notebook(path) for path in tqdm(paths_test, desc='Test NBs')
]
df_test = (
    pd.concat(notebooks_test)
    .set_index('id', append=True)
    .swaplevel()
    .sort_index(level='id', sort_remaining=False)
)
# Out:
# Test NBs: 100%|██████████| 4/4 [00:01<00:00,  2.19it/s]

# %%
X_test = tfidf.transform(df_test['source'].astype(str))
X_test = sparse.hstack((
    X_test,
    np.where(
        df_test['cell_type'] == 'code',
        df_test.groupby(['id', 'cell_type']).cumcount().to_numpy() + 1,
        0,
    ).reshape(-1, 1)
))

# %%
y_infer = pd.DataFrame({'rank': model.predict(X_test)}, index=df_test.index)
y_infer = y_infer.sort_values(['id', 'rank']).reset_index('cell_id').groupby('id')['cell_id'].apply(list)
y_infer
# Out:
# id
# 0009d135ece78d    [ddfd239c, c6cd22db, 1372ae9b, 90ed07ab, 7f388a41, 2843a25a, 06dbf8cf, f9893819, 8cb8d28a, ba55e576, 39e937ec, e25aa...
# 0010483c12ba9b                       [54c7cab3, fe66203e, 7844d5f8, 5ce8863c, 4a0777c4, 4a32c095, 02a0be6d, 4703bb6d, 7f270e34, 865ad516]
# 0010a919d60e4f    [aafc3d23, 80e077ec, b190ebb4, ed415c3c, b7578789, 322850af, c069ed33, 868c4eae, 80433cf3, 3bff2378, bbff12d4, bd8fb...
# 0028856e09c5b7                                                                                   [012c9d02, d22526d1, 3ae7ece3, eb293dfc]
# Name: cell_id, dtype: object

# %%
y_submit = (
    y_infer
    .apply(' '.join)
    .rename_axis('id')
    .rename('cell_order')
)
y_submit
# Out:
# id
# 0009d135ece78d       ddfd239c c6cd22db 1372ae9b 90ed07ab 7f388a41 2843a25a 06dbf8cf f9893819 8cb8d28a ba55e576 39e937ec e25aa9bd 0a226b6a
# 0010483c12ba9b                                  54c7cab3 fe66203e 7844d5f8 5ce8863c 4a0777c4 4a32c095 02a0be6d 4703bb6d 7f270e34 865ad516
# 0010a919d60e4f    aafc3d23 80e077ec b190ebb4 ed415c3c b7578789 322850af c069ed33 868c4eae 80433cf3 3bff2378 bbff12d4 bd8fbd76 8ce62db4...
# 0028856e09c5b7                                                                                        012c9d02 d22526d1 3ae7ece3 eb293dfc
# Name: cell_order, dtype: object

# %%
y_submit.to_csv('submission.csv', index=False)

# %%
# !kaggle competitions submit -c AI4Code -f submission.csv -m "Message"
# Out:
# 100% 812/812 [00:01<00:00, 531B/s]
# 400 - Bad Request
